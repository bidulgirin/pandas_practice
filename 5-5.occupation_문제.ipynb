# %%
import pandas as pd

# %% [markdown]
# # 문제1. user_id를 인덱스로 사용하여 occupation.tsv 데이터프레임 읽기

# %%
df = pd.read_csv("./data/occupation.tsv", sep="|",  index_col="user_id")

df.head()
# Out:
#          age gender  occupation zip_code
# user_id
# 1         24      M  technician    85711
# 2         53      F       other    94043
# 3         23      M      writer    32067
# 4         24      M  technician    43537
# 5         33      F       other    15213

# %%
df.shape
# Out:
# (943, 4)

# %% [markdown]
# # 문제2. 각 occupation별 age의 평균 구하기

# %%
groups = df.groupby("occupation")

# %%
groups

# %%
for key, group in groups:
    print("keys : ", key)
    print("group : ", group)
# Out:
# keys :  administrator
# group :           age gender     occupation zip_code
# user_id
# 7         57      M  administrator    91344
# 8         36      M  administrator    05201
# 34        38      F  administrator    42141
# 42        30      M  administrator    17870
# 48        45      M  administrator    12550
# ...      ...    ...            ...      ...
# 873       48      F  administrator    33763
# 879       33      F  administrator    55337
# 891       51      F  administrator    03062
# 922       29      F  administrator    21114
# 940       32      M  administrator    02215
#
# [79 rows x 4 columns]
# keys :  artist
# group :           age gender occupation zip_code
# user_id
# 23        30      F     artist    48197
# 24        21      F     artist    94533
# 31        24      M     artist    10003
# 96        25      F     artist    75206
# 97        43      M     artist    98006
# 123       48      F     artist    20008
# 146       45      M     artist    83814
# ...

# %%
age_avg = groups[["age"]].mean()

# %%
age_avg
# Out:
#                      age
# occupation
# administrator  38.746835
# artist         31.392857
# doctor         43.571429
# educator       42.010526
# engineer       36.388060
# entertainment  29.222222
# executive      38.718750
# healthcare     41.562500
# homemaker      32.571429
# lawyer         36.750000
# librarian      40.000000
# marketing      37.615385
# none           26.555556
# other          34.523810
# programmer     33.121212
# retired        63.071429
# salesman       35.666667
# scientist      35.548387
# student        22.081633
# technician     33.148148
# writer         36.311111

# %% [markdown]
# # 문제3. 각 occupation 별 남자의 비율 구하기
# - 단, 남자 비율의 내림차순으로 정렬하여 출력하기

# %%
groups[["gender"]]

# %%
df.shape[0]
# Out:
# 943

# %%
# 비율구하기
# (남자/ 사람) * 100 이렇게 해버릴까?

# 조건을 사용해서 남자의 비율을 구해보자 
len(df[df["gender"] == "M"])
# Out:
# 670

# %%
#groups[["gender"]].describe()

# 그룹 각각의 개수

occupation = df.groupby(["occupation"])

# %%
#groups[["gender"]].describe()

gg = df.groupby(["occupation"])["gender"]

# %%
# for i, g in gg:
#     print(i)
#     print(g.count())
man = df[df["gender"] == "M"]

man_length = man.groupby("occupation")["gender"].count()

oh_result = man_length / groups["gender"].count()

oh_result.sort_values(ascending= False)
# Out:
# occupation
# doctor           1.000000
# engineer         0.970149
# technician       0.962963
# retired          0.928571
# programmer       0.909091
# executive        0.906250
# scientist        0.903226
# entertainment    0.888889
# lawyer           0.833333
# salesman         0.750000
# educator         0.726316
# student          0.693878
# other            0.657143
# marketing        0.615385
# writer           0.577778
# none             0.555556
# administrator    0.544304
# artist           0.535714
# librarian        0.431373
# healthcare       0.312500
# homemaker        0.142857
# Name: gender, dtype: float64

# %%
# Out:
# 79
# 28
# 7
# 95
# 67
# 18
# 32
# 16
# 7
# 12
# 51
# 26
# 9
# 105
# 66
# 14
# 12
# 31
# 196
# 27
# 45

# %%
result.sum() # 1이 나오면 된거쥬~? => 안된거쥬~
# Out:
# age         978.281839
# gender      978.281839
# zip_code    978.281839
# dtype: float64

# %% [markdown]
# # 문제4. occupation별 age의 최솟값, 최댓값 구하기

# %%
age_min_max = groups.agg[{"age" : ["min", "max"]}]
age_min_max
# Out:
#               age
#               min max
# occupation
# administrator  21  70
# artist         19  48
# doctor         28  64
# educator       23  63
# engineer       22  70
# entertainment  15  50
# executive      22  69
# healthcare     22  62
# homemaker      20  50
# lawyer         21  53
# librarian      23  69
# marketing      24  55
# none           11  55
# other          13  64
# programmer     20  63
# retired        51  73
# salesman       18  66
# scientist      23  55
# student         7  42
# technician     21  55
# writer         18  60

# %% [markdown]
# # 문제5. 각 occupation의 gender별 평균 age를 구하기

# %%
# occupation 이라는 컬럼??

# %%
df
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# ...      ...    ...            ...      ...
# 939       26      F        student    33319
# 940       32      M  administrator    02215
# 941       20      M        student    97229
# 942       48      F      librarian    78209
# 943       22      M        student    77841
#
# [943 rows x 4 columns]

# %%
groups_2 = df.groupby(["occupation", "gender"], observed = True)

for key, group in groups_2:
    print("keys : ", key)
    print("group : ", group)
# Out:
# keys :  ('administrator', 'F')
# group :           age gender     occupation zip_code
# user_id
# 34        38      F  administrator    42141
# 62        27      F  administrator    97214
# 72        48      F  administrator    73034
# 79        39      F  administrator    03755
# 80        34      F  administrator    52241
# 89        43      F  administrator    68106
# 131       59      F  administrator    15237
# 151       38      F  administrator    48103
# 174       30      F  administrator    52302
# 180       22      F  administrator    60202
# 225       51      F  administrator    58202
# 238       42      F  administrator    44124
# 266       62      F  administrator    78756
# 277       35      F  administrator    55406
# 296       43      F  administrator    16803
# 400       33      F  administrator    78213
# 436       30      F  administrator    17345
# 438       51      F  administrator    43204
# 439       23      F  administrator    20817
# ...

# %%
groups_2[["age"]].mean()
# Out:
#                             age
# occupation    gender
# administrator F       40.638889
#               M       37.162791
# artist        F       30.307692
#               M       32.333333
# doctor        M       43.571429
# educator      F       39.115385
#               M       43.101449
# engineer      F       29.500000
#               M       36.600000
# entertainment F       31.000000
#               M       29.000000
# executive     F       44.000000
#               M       38.172414
# healthcare    F       39.818182
#               M       45.400000
# homemaker     F       34.166667
#               M       23.000000
# lawyer        F       39.500000
#               M       36.200000
# librarian     F       40.000000
#               M       40.000000
# marketing     F       37.200000
#               M       37.875000
# none          F       36.500000
#               M       18.600000
# other         F       35.472222
#               M       34.028986
# ...

# %%
# 람다로 풀어보기


lambda_result_group = df.groupby("occupation").apply(lambda x :  sum(x["gender"]  == "M") / len(x["gender"])).sort_values( ascending = False)

lambda_result_group
# Out:
# C:\Users\ITSC\AppData\Local\Temp\ipykernel_8000\1856915540.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   lambda_result_group = df.groupby("occupation").apply(lambda x :  sum(x["gender"]  == "M") / len(x["gender"])).sort_values( ascending = False)
# occupation
# doctor           1.000000
# engineer         0.970149
# technician       0.962963
# retired          0.928571
# programmer       0.909091
# executive        0.906250
# scientist        0.903226
# entertainment    0.888889
# lawyer           0.833333
# salesman         0.750000
# educator         0.726316
# student          0.693878
# other            0.657143
# marketing        0.615385
# writer           0.577778
# ...
