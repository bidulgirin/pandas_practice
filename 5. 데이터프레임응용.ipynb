# %% [markdown]
# # 함수 매핑
#
# - 시리즈 또는 데이터프레임의 개별 원소를 특정 함수에 일대일 대응시키는 과정
# - 사용자가 직접 만든 함수를 적용할 수 있기 때문에 파아스 기본 함수로 처리하기 어려운 복잡한 연산을 적용하는 것이 가능

# %% [markdown]
# ## 개별 원소에 함수 매핑

# %% [markdown]
# ### 시리즈 원소에 함수 매핑
# - 시리즈에 map() 을 적용하면 이자로 전달받는 매핑 함수에 시리즈이 모든 원소를 하나씩 입력하고 리턴값을 받음
# - 시리즈 원소의 개수만큼 리턴값을 받아서 같은 크기의 시리즈 객체로 변환

# %%
import pandas as pd
import seaborn as sns

# %%
titanic = sns.load_dataset("titanic")

# %%
df = titanic.loc[:, ["age","fare","class"]]

# %%
df.head()
# Out:
#     age     fare  class
# 0  22.0   7.2500  Third
# 1  38.0  71.2833  First
# 2  26.0   7.9250  Third
# 3  35.0  53.1000  First
# 4  35.0   8.0500  Third

# %%
def add_10(n): # 10을 더하는 함수
    return n + 10

# %%
df["age"].map(add_10)
# Out:
# 0      32.0
# 1      48.0
# 2      36.0
# 3      45.0
# 4      45.0
#        ...
# 886    37.0
# 887    29.0
# 888     NaN
# 889    36.0
# 890    42.0
# Name: age, Length: 891, dtype: float64

# %%
# 한번사용하고 말 함수를 선언하는것은 매우 비효율적
# 그래서 익명함수를 쓴다

# %%
# lambda expression 람다 표현식

# %%
df["age"].map(lambda x : x + 10)
# Out:
# 0      32.0
# 1      48.0
# 2      36.0
# 3      45.0
# 4      45.0
#        ...
# 886    37.0
# 887    29.0
# 888     NaN
# 889    36.0
# 890    42.0
# Name: age, Length: 891, dtype: float64

# %%
# 학계분을 싫어한다 => 구현해본적없음!

# %%
# 온몸 비틀기는 덕목이다!
# 파이썬 기초를 알면 다 할 수 있다!
# 파이썬의 기초를 탄탄하게!

# %% [markdown]
# ### 데이터프레임 원소에 함수 매핑

# %%
df.head()
# Out:
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500

# %%
df.map(lambda x : x + 10)
# Out:
#       age     fare
# 0    32.0  17.2500
# 1    48.0  81.2833
# 2    36.0  17.9250
# 3    45.0  63.1000
# 4    45.0  18.0500
# ..    ...      ...
# 886  37.0  23.0000
# 887  29.0  40.0000
# 888   NaN  33.4500
# 889  36.0  40.0000
# 890  42.0  17.7500
#
# [891 rows x 2 columns]

# %%
# 하나하나의 원소에 mapping 하는 것은 쉽다!
# 객체에 매핑하려면???

# %% [markdown]
# ## 데이터프레임 객체에 함수 매핑

# %%
df.apply(lambda x: x["age"] + x["fare"], axis=1)
# Out:
# 0       29.2500
# 1      109.2833
# 2       33.9250
# 3       88.1000
# 4       43.0500
#          ...
# 886     40.0000
# 887     49.0000
# 888         NaN
# 889     56.0000
# 890     39.7500
# Length: 891, dtype: float64

# %% [markdown]
# # 열 분리
#
# - 하나의 열이 여러 가지 정보를 담고 있으면 정보를 분리해야함
# - 어떤 열에 연월일 정보가 있을 때 연, 월, 일을 구분하여 3개의 열로 분리

# %%
df = pd.read_excel("./data/주가데이터.xlsx")

# %%
df.head()
# Out:
#          연월일   당일종가  전일종가     시가     고가     저가     거래량
# 0 2018-07-02  10100   600  10850  10900  10000  137977
# 1 2018-06-29  10700   300  10550  10900   9990  170253
# 2 2018-06-28  10400   500  10900  10950  10150  155769
# 3 2018-06-27  10900   100  10800  11050  10500  133548
# 4 2018-06-26  10800   350  10900  11000  10700   63039

# %%
df.shape
# Out:
# (20, 7)

# %%
df.describe()
# Out:
#                        연월일          당일종가         전일종가            시가  \
# count                   20     20.000000    20.000000     20.000000
# mean   2018-06-17 04:48:00  11662.500000   345.000000  11755.000000
# min    2018-06-01 00:00:00  10100.000000     0.000000  10550.000000
# 25%    2018-06-10 06:00:00  11087.500000   100.000000  11125.000000
# 50%    2018-06-18 12:00:00  11725.000000   250.000000  11800.000000
# 75%    2018-06-25 06:00:00  11962.500000   387.500000  12050.000000
# max    2018-07-02 00:00:00  13450.000000  1400.000000  13600.000000
# std                    NaN    927.060294   387.943295    865.250192
#
#                  고가            저가            거래량
# count     20.000000     20.000000      20.000000
# mean   12015.000000  11374.500000  158014.150000
# min    10900.000000   9990.000000   25171.000000
# 25%    11350.000000  10737.500000   58323.250000
# 50%    12025.000000  11500.000000  134176.500000
# 75%    12262.500000  11912.500000  185836.000000
# max    13700.000000  13150.000000  558148.000000
# std      907.729962    884.369981  134473.512003

# %%
df.dtypes
# Out:
# 연월일     datetime64[ns]
# 당일종가             int64
# 전일종가             int64
# 시가               int64
# 고가               int64
# 저가               int64
# 거래량              int64
# dtype: object

# %%
# dt 메서드 datetime 메서드임(datetime 에서만 쓸 수 있다)
df["연월일"]
# Out:
# 0    2018-07-02
# 1    2018-06-29
# 2    2018-06-28
# 3    2018-06-27
# 4    2018-06-26
# 5    2018-06-25
# 6    2018-06-22
# 7    2018-06-21
# 8    2018-06-20
# 9    2018-06-19
# 10   2018-06-18
# 11   2018-06-15
# 12   2018-06-14
# 13   2018-06-12
# 14   2018-06-11
# 15   2018-06-08
# 16   2018-06-07
# 17   2018-06-05
# 18   2018-06-04
# 19   2018-06-01
# Name: 연월일, dtype: datetime64[ns]

# %%
df["연"] = df["연월일"].dt.year

# %%
df["월"] = df["연월일"].dt.month

# %%
df["일"] = df["연월일"].dt.day

# %%
df.head()
# Out:
#          연월일   당일종가  전일종가     시가     고가     저가     거래량     연  월   일
# 0 2018-07-02  10100   600  10850  10900  10000  137977  2018  7   2
# 1 2018-06-29  10700   300  10550  10900   9990  170253  2018  6  29
# 2 2018-06-28  10400   500  10900  10950  10150  155769  2018  6  28
# 3 2018-06-27  10900   100  10800  11050  10500  133548  2018  6  27
# 4 2018-06-26  10800   350  10900  11000  10700   63039  2018  6  26

# %%
df.dtypes
# Out:
# 연월일     datetime64[ns]
# 당일종가             int64
# 전일종가             int64
# 시가               int64
# 고가               int64
# 저가               int64
# 거래량              int64
# 연                int32
# 월                int32
# 일                int32
# dtype: object

# %%
# 문자열로 읽힐경우 
# 문자열 => datetime => dt 메서드 이용
# str 메서드이용 **

df["연월일"] = df["연월일"].astype(str) # 이용하기위해 문자열로 변환

# %%
df.dtypes
# Out:
# 연월일     object
# 당일종가     int64
# 전일종가     int64
# 시가       int64
# 고가       int64
# 저가       int64
# 거래량      int64
# 연        int32
# 월        int32
# 일        int32
# dtype: object

# %%
# 공식문서에 str. 로 검색하면 뭐 다온다....!

# %%
df["연월일"].str.split("-")
# Out:
# 0     [2018, 07, 02]
# 1     [2018, 06, 29]
# 2     [2018, 06, 28]
# 3     [2018, 06, 27]
# 4     [2018, 06, 26]
# 5     [2018, 06, 25]
# 6     [2018, 06, 22]
# 7     [2018, 06, 21]
# 8     [2018, 06, 20]
# 9     [2018, 06, 19]
# 10    [2018, 06, 18]
# 11    [2018, 06, 15]
# 12    [2018, 06, 14]
# 13    [2018, 06, 12]
# 14    [2018, 06, 11]
# 15    [2018, 06, 08]
# 16    [2018, 06, 07]
# 17    [2018, 06, 05]
# 18    [2018, 06, 04]
# 19    [2018, 06, 01]
# Name: 연월일, dtype: object

# %%
date =  df["연월일"].str.split("-")
# str.get 해줘야!!! 된다!!!!
df["연"] = date.str.get(0).astype(int)
df["월"] = date.str.get(1).astype(int)
df["일"] = date.str.get(2).astype(int)

# %%
df.head()
# Out:
#           연월일   당일종가  전일종가     시가     고가     저가     거래량     연  월   일
# 0  2018-07-02  10100   600  10850  10900  10000  137977  2018  7   2
# 1  2018-06-29  10700   300  10550  10900   9990  170253  2018  6  29
# 2  2018-06-28  10400   500  10900  10950  10150  155769  2018  6  28
# 3  2018-06-27  10900   100  10800  11050  10500  133548  2018  6  27
# 4  2018-06-26  10800   350  10900  11000  10700   63039  2018  6  26

# %%
df.dtypes
# Out:
# 연월일     object
# 당일종가     int64
# 전일종가     int64
# 시가       int64
# 고가       int64
# 저가       int64
# 거래량      int64
# 연        int64
# 월        int64
# 일        int64
# dtype: object

# %%
# 지루하고 현학적이다!
df["연월일"].str[:4]
# Out:
# 0     2018
# 1     2018
# 2     2018
# 3     2018
# 4     2018
# 5     2018
# 6     2018
# 7     2018
# 8     2018
# 9     2018
# 10    2018
# 11    2018
# 12    2018
# 13    2018
# 14    2018
# 15    2018
# 16    2018
# 17    2018
# 18    2018
# 19    2018
# Name: 연월일, dtype: object

# %%
df["연월일"].str[5:7]
# Out:
# 0     07
# 1     06
# 2     06
# 3     06
# 4     06
# 5     06
# 6     06
# 7     06
# 8     06
# 9     06
# 10    06
# 11    06
# 12    06
# 13    06
# 14    06
# 15    06
# 16    06
# 17    06
# 18    06
# 19    06
# Name: 연월일, dtype: object

# %%
df["연월일"].str[8:]
# Out:
# 0     02
# 1     29
# 2     28
# 3     27
# 4     26
# 5     25
# 6     22
# 7     21
# 8     20
# 9     19
# 10    18
# 11    15
# 12    14
# 13    12
# 14    11
# 15    08
# 16    07
# 17    05
# 18    04
# 19    01
# Name: 연월일, dtype: object

# %% [markdown]
# # 필터링 (매우매우매우 중요)
#
# - 시리즈 또는 데이터프레임의 데이터 중에서 특정 조건식을 만족하는 원소만 따로 추출

# %% [markdown]
# ## 불리언 인덱싱
#
# - 시리즈 객체에 어떤 조건식을 적용하면 각 원소에 대해 참/거짓을 판별하여 불리언 값으로 구성된 시리즈를 반환
# - 이때 참에 해당하는 데이터 값을 따로 선택할 수 있음

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
# age 가 10이상인 데이터를 필터링하고자 한다!!!!!!!!!
titanic["age"] >= 10
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: age, Length: 891, dtype: bool

# %%
titanic.loc[titanic["age"] < 20]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 7           0       3    male   2.0      3      1  21.0750        S   Third
# 9           1       2  female  14.0      1      0  30.0708        C  Second
# 10          1       3  female   4.0      1      1  16.7000        S   Third
# 14          0       3  female  14.0      0      0   7.8542        S   Third
# 16          0       3    male   2.0      4      1  29.1250        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 855         1       3  female  18.0      0      1   9.3500        S   Third
# 869         1       3    male   4.0      1      1  11.1333        S   Third
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 877         0       3    male  19.0      0      0   7.8958        S   Third
# 887         1       1  female  19.0      0      0  30.0000        S   First
#
#        who  adult_male deck  embark_town alive  alone
# 7    child       False  NaN  Southampton    no  False
# 9    child       False  NaN    Cherbourg   yes  False
# 10   child       False    G  Southampton   yes  False
# 14   child       False  NaN  Southampton    no   True
# 16   child       False  NaN   Queenstown    no  False
# ..     ...         ...  ...          ...   ...    ...
# 855  woman       False  NaN  Southampton   yes  False
# 869  child       False  NaN  Southampton   yes  False
# 875  child       False  NaN    Cherbourg   yes   True
# 877    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
#
# [164 rows x 15 columns]

# %%
# 여러조건을 하고 싶으면 and 도 or 도 가능하다!

# titanic 데이터에서 age 컬럼의값이 10이상이고 20미만인 데이터 필터링

df_teenage = titanic.loc[(titanic["age"] >=10) & (titanic["age"] <20) & (titanic["alive"] == "no"), ["age", "class", "who", "sex"]]

# and 는 & 기호를 작성해야한다...

# %%
df_teenage.head(20)
# Out:
#       age   class    who     sex
# 14   14.0   Third  child  female
# 27   19.0   First    man    male
# 38   18.0   Third  woman  female
# 49   18.0   Third  woman  female
# 59   11.0   Third  child    male
# 67   19.0   Third    man    male
# 71   16.0   Third  woman  female
# 86   16.0   Third    man    male
# 111  14.5   Third  child  female
# 114  17.0   Third  woman  female
# 138  16.0   Third    man    male
# 143  19.0   Third    man    male
# 144  18.0  Second    man    male
# 145  19.0  Second    man    male
# 163  17.0   Third    man    male
# 175  18.0   Third    man    male
# 191  19.0  Second    man    male
# 228  18.0  Second    man    male
# 238  19.0  Second    man    male
# 266  16.0   Third    man    male

# %%
# or은 | 을 쓰면 되겠죵?

# %% [markdown]
# ## isin() 메소드 활용
#
# - 데이터프레임의 열에 isin() 메소드를 적용하면 특정 값을 갖니 행들을 추출할 수 있음

# %%
titanic["sibsp"] # 같이 탄 형제나 배우자의 수...
# Out:
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 886    0
# 887    0
# 888    1
# 889    0
# 890    0
# Name: sibsp, Length: 891, dtype: int64

# %%
titanic.loc[titanic["sibsp"].isin([3,4,5])]

# 필터링만 한다면 loc 을 안써도 된다
not_loc = titanic[titanic["sibsp"].isin([3,4,5])]
not_loc.head()
# Out:
#     survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 7          0       3    male   2.0      3      1   21.0750        S  Third
# 16         0       3    male   2.0      4      1   29.1250        Q  Third
# 24         0       3  female   8.0      3      1   21.0750        S  Third
# 27         0       1    male  19.0      3      2  263.0000        S  First
# 50         0       3    male   7.0      4      1   39.6875        S  Third
#
#       who  adult_male deck  embark_town alive  alone
# 7   child       False  NaN  Southampton    no  False
# 16  child       False  NaN   Queenstown    no  False
# 24  child       False  NaN  Southampton    no  False
# 27    man        True    C  Southampton    no  False
# 50  child       False  NaN  Southampton    no  False

# %%
# 숙련도가 높아야... 겨우겨우... 입구컷...

# %% [markdown]
# # 데이터프레임 합치기

# %%
df1 = pd.DataFrame({
        "a": ["a0","a1","a2","a3"],
        "b": ["b0","b1","b2","b3"],
        "c": ["c0","c1","c2","c3"]}, 
        index =  [0,1,2,3])

df2 = pd.DataFrame({
        "a": ["a2","a3","a4","a5"],
        "b": ["b2","b3","b4","b5"],
        "c": ["c2","c3","c4","c5"]},
        index =  [2,3,4,5])

# %%
df1
# Out:
#     a   b   c
# 2  a0  b0  c0
# 3  a1  b1  c1
# 4  a2  b2  c2
# 5  a3  b3  c3

# %%
df2
# Out:
#     a   b   c
# 2  a2  b2  c2
# 3  a3  b3  c3
# 4  a4  b4  c4
# 5  a5  b5  c5

# %%
# 2개의 데이터프레임을 행 방향으로 연결
result1 = pd.concat([df1,df2] , axis = 0)

# %%
result1
# Out:
#     a   b   c
# 2  a0  b0  c0
# 3  a1  b1  c1
# 4  a2  b2  c2
# 5  a3  b3  c3
# 2  a2  b2  c2
# 3  a3  b3  c3
# 4  a4  b4  c4
# 5  a5  b5  c5

# %%
# 기존 행 인덱스를 무시하고 새로운 행 인덱스를 설정
result1 = pd.concat([df1,df2] , axis = 0, ignore_index =True)

# %% [markdown]
# # 중요!!!!!!

# %%
result1
# Out:
#     a   b   c
# 0  a0  b0  c0
# 1  a1  b1  c1
# 2  a2  b2  c2
# 3  a3  b3  c3
# 4  a2  b2  c2
# 5  a3  b3  c3
# 6  a4  b4  c4
# 7  a5  b5  c5

# %%
result3 = pd.concat([df1,df2])

# %%
result2 # index 기준으로 붙기 때문에 NaN 값이 나온다~
# Out:
#      a    b    c    a    b    c
# 2   a0   b0   c0  NaN  NaN  NaN
# 3   a1   b1   c1  NaN  NaN  NaN
# 4   a2   b2   c2   a2   b2   c2
# 5   a3   b3   c3   a3   b3   c3
# 6  NaN  NaN  NaN   a4   b4   c4
# 7  NaN  NaN  NaN   a5   b5   c5

# %%
# 연결할 데이터 프레임의 교집합을 기준으로 연결
result3_in = pd.concat([df1, df2], axis = 1, join ="inner")
result3_in # 양쪽에 모두 가지고 있는 index 만 출력된다리~
# Out:
#     a   b   c   a   b   c
# 2  a0  b0  c0  a2  b2  c2
# 3  a1  b1  c1  a3  b3  c3

# %%
# 데이터 프레임과 시리즈의 연결
sr1 = pd.Series(["e0","e1","e2","e3"], name="e")
sr2 = pd.Series(["f0","f1","f2"], name="f", index = [3,4,5])
sr3 = pd.Series(["g0","g1","g2","g3"], name="g")

# %%
sr1
# Out:
# 0    e0
# 1    e1
# 2    e2
# 3    e3
# Name: e, dtype: object

# %%
sr2
# Out:
# 3    f0
# 4    f1
# 5    f2
# Name: f, dtype: object

# %%
sr3
# Out:
# 0    g0
# 1    g1
# 2    g2
# 3    g3
# Name: g, dtype: object

# %%
sr_result = pd.concat([df1, sr1], axis = 1)

# %%
sr_result
# Out:
#     a   b   c   e
# 0  a0  b0  c0  e0
# 1  a1  b1  c1  e1
# 2  a2  b2  c2  e2
# 3  a3  b3  c3  e3

# %%
# 행방향은?
sr_result2 = pd.concat([df1, sr1], axis = 0)

# %%
sr_result2
# Out:
#      a    b    c    e
# 0   a0   b0   c0  NaN
# 1   a1   b1   c1  NaN
# 2   a2   b2   c2  NaN
# 3   a3   b3   c3  NaN
# 0  NaN  NaN  NaN   e0
# 1  NaN  NaN  NaN   e1
# 2  NaN  NaN  NaN   e2
# 3  NaN  NaN  NaN   e3

# %%
df2
# Out:
#     a   b   c
# 2  a2  b2  c2
# 3  a3  b3  c3
# 4  a4  b4  c4
# 5  a5  b5  c5

# %%
sr2
# Out:
# 3    f0
# 4    f1
# 5    f2
# Name: f, dtype: object

# %%
sr_result3 = pd.concat([df2,sr2], axis = 1)

# %%
sr_result3
# Out:
#     a   b   c    f
# 2  a2  b2  c2  NaN
# 3  a3  b3  c3   f0
# 4  a4  b4  c4   f1
# 5  a5  b5  c5   f2

# %%
# 시리즈와 시리즈의 연결
series_result = pd.concat([sr1, sr3], axis = 1)

# %%
series_result
# Out:
#     e   g
# 0  e0  g0
# 1  e1  g1
# 2  e2  g2
# 3  e3  g3

# %%
sr1
# Out:
# 0    e0
# 1    e1
# 2    e2
# 3    e3
# Name: e, dtype: object

# %%
sr3
# Out:
# 0    g0
# 1    g1
# 2    g2
# 3    g3
# Name: g, dtype: object

# %%
# sr1 과 sr3 를 행 방향으로 연결
series_result2 = pd.concat([sr1, sr3], axis = 0)

# %%
series_result2
# Out:
# 0    e0
# 1    e1
# 2    e2
# 3    e3
# 0    g0
# 1    g1
# 2    g2
# 3    g3
# dtype: object

# %%
series_result2 = pd.concat([sr1, sr3], axis = 0, ignore_index = True)

# %%
series_result2
# Out:
# 0    e0
# 1    e1
# 2    e2
# 3    e3
# 4    g0
# 5    g1
# 6    g2
# 7    g3
# dtype: object

# %% [markdown]
# ## 데이터프레임 병합!
#
# - merge()
# - SQL 의 join 명령어와 비슷한 방식으로, 어떤 기준에 의해 두 데이터프렝미을 병합하는 개념
# - 병합의 기준이 되는 열이나 인덱스를 키라고 부름
# - 키가 되는 열이나 인덱스는 반드시 양쪽 데이터 프레임에 존재

# %%
df1 = pd.read_excel("./data/stock price.xlsx")

df2 = pd.read_excel("./data/stock valuation.xlsx")

# %%
df1.head()
# Out:
#        id stock_name          value   price
# 0  128940       한미약품   59385.666667  421000
# 1  130960     CJ E&M   58540.666667   98900
# 2  138250      엔에스쇼핑   14558.666667   13200
# 3  139480        이마트  239230.833333  254500
# 4  142280     녹십자엠에스     468.833333   10200

# %%
df2.head()
# Out:
#        id     name           eps     bps        per       pbr
# 0  130960   CJ E&M   6301.333333   54068  15.695091  1.829178
# 1  136480       하림    274.166667    3551  11.489362  0.887074
# 2  138040  메리츠금융지주   2122.333333   14894   6.313806  0.899691
# 3  139480      이마트  18268.166667  295780  13.931338  0.860437
# 4  145990      삼양사   5741.000000  108090  14.283226  0.758627

# %%
# 병합해보자 ~
df1.shape
# Out:
# (10, 4)

# %%
df2.shape
# Out:
# (10, 6)

# %%
# 워렌버핏 : per 볼줄 모르면 주식하지 마라

# %%
# 95퍼 날린 친구는 분석가가 직업이다

# %%
# 뭘 배운거냐?

# %%
# 데이터프레임 합치기 - 교집합
merge_inner = pd.merge(df1, df2, on = None, how = "inner") # on :결합조건 / how: 교집합/합집합...등등...

# on = None 두 데이터 프레임에 공통으로 속하는 모든 열을 기준으로 병합
# how: 기준은 열의 데이터를 비교한다

# %%
merge_inner
# Out:
#        id stock_name          value   price    name           eps     bps  \
# 0  130960     CJ E&M   58540.666667   98900  CJ E&M   6301.333333   54068
# 1  139480        이마트  239230.833333  254500     이마트  18268.166667  295780
# 2  145990        삼양사   82750.000000   82000     삼양사   5741.000000  108090
# 3  185750        종근당   40293.666667  100500     종근당   3990.333333   40684
# 4  204210     모두투어리츠    3093.333333    3475  모두투어리츠     85.166667    5335
#
#          per       pbr
# 0  15.695091  1.829178
# 1  13.931338  0.860437
# 2  14.283226  0.758627
# 3  25.185866  2.470259
# 4  40.802348  0.651359

# %%
merge_inner.shape
# Out:
# (5, 9)

# %%
# 데이터프레임 합치기 - 합집합
# on = "id" : id 열을 키로 병합
# how = "outer" : 기준이 되는 id 열의 데이ㅓㅌ가 어느 한쪽에서 속하더라도고 ㅎ폼

merge_outer = pd.merge(df1, df2, on = "id", how = "outer") # on :결합조건 / how: 교집합/합집합...등등...
#merge_outer = pd.merge(df1, df2, on = None, how = "outer")

# %%
merge_outer.shape
# Out:
# (15, 9)

# %%
merge_left = pd.merge(df1, df2, how = "left", left_on="stock_name", right_on="name") 
# left_on : left 측에서 사용할 조건 
# right_on : right 측에서 사용할 조건 

# 둘 다 써줘야 left_on 과 right_on 의 속성이 같은것끼리 나온다요!!!!!!!!!


# how 에 쓸 수 있는것 inner, outer, left, right...이렇게 할수있다.

# %%
merge_left
# Out:
#      id_x stock_name          value   price      id_y    name           eps  \
# 0  128940       한미약품   59385.666667  421000       NaN     NaN           NaN
# 1  130960     CJ E&M   58540.666667   98900  130960.0  CJ E&M   6301.333333
# 2  138250      엔에스쇼핑   14558.666667   13200       NaN     NaN           NaN
# 3  139480        이마트  239230.833333  254500  139480.0     이마트  18268.166667
# 4  142280     녹십자엠에스     468.833333   10200       NaN     NaN           NaN
# 5  145990        삼양사   82750.000000   82000  145990.0     삼양사   5741.000000
# 6  185750        종근당   40293.666667  100500  185750.0     종근당   3990.333333
# 7  192400      쿠쿠홀딩스  179204.666667  177500       NaN     NaN           NaN
# 8  199800         툴젠   -2514.333333  115400       NaN     NaN           NaN
# 9  204210     모두투어리츠    3093.333333    3475  204210.0  모두투어리츠     85.166667
#
#         bps        per       pbr
# 0       NaN        NaN       NaN
# 1   54068.0  15.695091  1.829178
# 2       NaN        NaN       NaN
# 3  295780.0  13.931338  0.860437
# 4       NaN        NaN       NaN
# 5  108090.0  14.283226  0.758627
# 6   40684.0  25.185866  2.470259
# 7       NaN        NaN       NaN
# 8       NaN        NaN       NaN
# 9    5335.0  40.802348  0.651359

# %%
merge_right= pd.merge(df1, df2, how = "right", left_on="stock_name", right_on="name")

# %%
merge_right
# Out:
#        id_x stock_name          value     price    id_y       name  \
# 0  130960.0     CJ E&M   58540.666667   98900.0  130960     CJ E&M
# 1       NaN        NaN            NaN       NaN  136480         하림
# 2       NaN        NaN            NaN       NaN  138040    메리츠금융지주
# 3  139480.0        이마트  239230.833333  254500.0  139480        이마트
# 4  145990.0        삼양사   82750.000000   82000.0  145990        삼양사
# 5       NaN        NaN            NaN       NaN  161390      한국타이어
# 6       NaN        NaN            NaN       NaN  181710  NHN엔터테인먼트
# 7  185750.0        종근당   40293.666667  100500.0  185750        종근당
# 8  204210.0     모두투어리츠    3093.333333    3475.0  204210     모두투어리츠
# 9       NaN        NaN            NaN       NaN  207940   삼성바이오로직스
#
#             eps     bps        per       pbr
# 0   6301.333333   54068  15.695091  1.829178
# 1    274.166667    3551  11.489362  0.887074
# 2   2122.333333   14894   6.313806  0.899691
# 3  18268.166667  295780  13.931338  0.860437
# 4   5741.000000  108090  14.283226  0.758627
# 5   5648.500000   51341   7.453306  0.820007
# 6   2110.166667   78434  30.755864  0.827447
# 7   3990.333333   40684  25.185866  2.470259
# 8     85.166667    5335  40.802348  0.651359
# 9   4644.166667   60099  89.790059  6.938551

# %% [markdown]
# ## 데이터프레임 결합
#
# - join()
# - merge() 함수를 기반으로 만들어져 기본 작동방식이 비슷하지만 두 데이터 프레임의 <b>행 인덱스를 기준</b>으로 결합하는 점이 차이점

# %%
df1.head()
# Out:
#        id stock_name          value   price
# 0  128940       한미약품   59385.666667  421000
# 1  130960     CJ E&M   58540.666667   98900
# 2  138250      엔에스쇼핑   14558.666667   13200
# 3  139480        이마트  239230.833333  254500
# 4  142280     녹십자엠에스     468.833333   10200

# %%
df1 = df1.set_index("id")

# %%
df2 = df2.set_index("id")

# %%
df1
# Out:
#        stock_name          value   price
# id
# 128940       한미약품   59385.666667  421000
# 130960     CJ E&M   58540.666667   98900
# 138250      엔에스쇼핑   14558.666667   13200
# 139480        이마트  239230.833333  254500
# 142280     녹십자엠에스     468.833333   10200
# 145990        삼양사   82750.000000   82000
# 185750        종근당   40293.666667  100500
# 192400      쿠쿠홀딩스  179204.666667  177500
# 199800         툴젠   -2514.333333  115400
# 204210     모두투어리츠    3093.333333    3475

# %%
df2
# Out:
#              name           eps     bps        per       pbr
# id
# 130960     CJ E&M   6301.333333   54068  15.695091  1.829178
# 136480         하림    274.166667    3551  11.489362  0.887074
# 138040    메리츠금융지주   2122.333333   14894   6.313806  0.899691
# 139480        이마트  18268.166667  295780  13.931338  0.860437
# 145990        삼양사   5741.000000  108090  14.283226  0.758627
# 161390      한국타이어   5648.500000   51341   7.453306  0.820007
# 181710  NHN엔터테인먼트   2110.166667   78434  30.755864  0.827447
# 185750        종근당   3990.333333   40684  25.185866  2.470259
# 204210     모두투어리츠     85.166667    5335  40.802348  0.651359
# 207940   삼성바이오로직스   4644.166667   60099  89.790059  6.938551

# %% [markdown]
# # merge 는 dataframe, series 둘다 됨
#
# # 데이터프레임만 join 을 슬수있다!!!!
#
# # 기준이 되는 데이터 프레임이 반드시 있다 => 뉘앙스가 다르다!!!!!
#
# # 그래서 기준이 기본 left 다!!!!

# %%
# df1 이 기준이고 df2 를 가져와서 join 을 하게됨
# 기본은 left outer 조인을 하게됨
df3 = df1.join(df2)

# %%
df3
# Out:
#        stock_name          value   price    name           eps       bps  \
# id
# 128940       한미약품   59385.666667  421000     NaN           NaN       NaN
# 130960     CJ E&M   58540.666667   98900  CJ E&M   6301.333333   54068.0
# 138250      엔에스쇼핑   14558.666667   13200     NaN           NaN       NaN
# 139480        이마트  239230.833333  254500     이마트  18268.166667  295780.0
# 142280     녹십자엠에스     468.833333   10200     NaN           NaN       NaN
# 145990        삼양사   82750.000000   82000     삼양사   5741.000000  108090.0
# 185750        종근당   40293.666667  100500     종근당   3990.333333   40684.0
# 192400      쿠쿠홀딩스  179204.666667  177500     NaN           NaN       NaN
# 199800         툴젠   -2514.333333  115400     NaN           NaN       NaN
# 204210     모두투어리츠    3093.333333    3475  모두투어리츠     85.166667    5335.0
#
#               per       pbr
# id
# 128940        NaN       NaN
# 130960  15.695091  1.829178
# 138250        NaN       NaN
# 139480  13.931338  0.860437
# 142280        NaN       NaN
# 145990  14.283226  0.758627
# 185750  25.185866  2.470259
# 192400        NaN       NaN
# 199800        NaN       NaN
# 204210  40.802348  0.651359

# %%
# outer 하기 싫은데여?
df5 = df1.join(df2, how="inner") # how 로 처리하거라~

# %%
df5
# Out:
#        stock_name          value   price    name           eps     bps  \
# id
# 130960     CJ E&M   58540.666667   98900  CJ E&M   6301.333333   54068
# 139480        이마트  239230.833333  254500     이마트  18268.166667  295780
# 145990        삼양사   82750.000000   82000     삼양사   5741.000000  108090
# 185750        종근당   40293.666667  100500     종근당   3990.333333   40684
# 204210     모두투어리츠    3093.333333    3475  모두투어리츠     85.166667    5335
#
#               per       pbr
# id
# 130960  15.695091  1.829178
# 139480  13.931338  0.860437
# 145990  14.283226  0.758627
# 185750  25.185866  2.470259
# 204210  40.802348  0.651359

# %% [markdown]
# # 그룹 연산
#
# - 데이터를 특정 기준에 따라 몇 개의 그룹으로 분할하여 처리하는 것
#
# - 데이터를 집계, 변환, 필터링하는데 효율적
#
# - groupby() 메소드의 처리 과정
#     1. 분할 : 데이터를 특정 조건에 의해 분할
#     2. 적용: 데이터를 집계, 변호나, 필터링하는데 필요한 메소드 적용
#     3. 결합 : 2단계의 처리 결과를 하나로 결합

# %%
# 반별 평균 이런거 그룹연산

# %%
# 분할 : group by 를 한다는 것은 2개의 데이터 프레임이 생긴것과 같다 => 분할
# 적용 : 1반에 국어점수의 평균... 2반에 국어점수 평균....
# 결합 : 결과물들을 합쳐서 1반의 평균과 2반의 평균의 데이터프레임 1개가 생긴다

# 이런 과정이 화면에 모두 안나옴!!!! 좀 그래서 구조를 잘알고 있어야한다~

# %% [markdown]
# ## 그룹 객체 만들기

# %% [markdown]
# ### 1개 열을 기준으로 그룹화

# %%
titanic = sns.load_dataset("titanic")

# %%
df = titanic.loc[:, ["age","sex","class","fare","survived"]]

# %%
df.head()
# Out:
#     age     sex  class     fare  survived
# 0  22.0    male  Third   7.2500         0
# 1  38.0  female  First  71.2833         1
# 2  26.0  female  Third   7.9250         1
# 3  35.0  female  First  53.1000         1
# 4  35.0    male  Third   8.0500         0

# %%
# class를 기준으로 그룹화 진행

grouped = df.groupby(["class"], observed=True) # observed=True 버전에 의해서 입력함
# numeric_only 도 원래 기본값이 True 였는뎅...ㅠ 바뀌었다


# observed=True
# class가 NaN 이런 데이터에 대비를 할꺼냐~ 말꺼냐~~~
# observed=True 하면 그냥 내꺼 쓰겠다 라는 뜻

# %%
grouped 
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x00000285DC8AA210> 
#  3개의 데이터프레임을 표현이 되어있는데 출력은 안해줌
# iterater 객체라서 반복문 가능

# %%
for key, group in grouped :
    print("*key : " , key)
    print("*group :" , group) # 분할이 된 상태이다
# Out:
# *key :  ('First',)
# *group :       age     sex  class     fare  survived
# 1    38.0  female  First  71.2833         1
# 3    35.0  female  First  53.1000         1
# 6    54.0    male  First  51.8625         0
# 11   58.0  female  First  26.5500         1
# 23   28.0    male  First  35.5000         1
# ..    ...     ...    ...      ...       ...
# 871  47.0  female  First  52.5542         1
# 872  33.0    male  First   5.0000         0
# 879  56.0  female  First  83.1583         1
# 887  19.0  female  First  30.0000         1
# 889  26.0    male  First  30.0000         1
#
# [216 rows x 5 columns]
# *key :  ('Second',)
# *group :       age     sex   class     fare  survived
# 9    14.0  female  Second  30.0708         1
# 15   55.0  female  Second  16.0000         1
# 17    NaN    male  Second  13.0000         1
# 20   35.0    male  Second  26.0000         0
# 21   34.0    male  Second  13.0000         1
# ..    ...     ...     ...      ...       ...
# 866  27.0  female  Second  13.8583         1
# 874  28.0  female  Second  24.0000         1
# 880  25.0  female  Second  26.0000         1
# 883  28.0    male  Second  10.5000         0
# 886  27.0    male  Second  13.0000         0
#
# [184 rows x 5 columns]
# *key :  ('Third',)
# *group :       age     sex  class     fare  survived
# 0    22.0    male  Third   7.2500         0
# 2    26.0  female  Third   7.9250         1
# 4    35.0    male  Third   8.0500         0
# 5     NaN    male  Third   8.4583         0
# 7     2.0    male  Third  21.0750         0
# ..    ...     ...    ...      ...       ...
# 882  22.0  female  Third  10.5167         0
# 884  25.0    male  Third   7.0500         0
# 885  39.0  female  Third  29.1250         0
# 888   NaN  female  Third  23.4500         0
# 890  32.0    male  Third   7.7500         0
#
# [491 rows x 5 columns]

# %%
# 연산 메서드를 적용시켜보자
avg = grouped.mean(numeric_only = True) # 이렇게 되면 숫자형만 나오네???????

# %%
avg
# Out:
#               age       fare  survived
# class
# First   38.233441  84.154687  0.629630
# Second  29.877630  20.662183  0.472826
# Third   25.140620  13.675550  0.242363

# %%
# 개별 그룹 선택하기
# group3 = grouped.get_group("Third) 
group3 = grouped.get_group(("Third",)) # 바뀌는 문법에 따라... 튜플을 사용했다...

# %%
group3.head() # 개인적으로는 필터링을 쓰지... 싶은감이있다...
# Out:
#     age     sex  class     fare  survived
# 0  22.0    male  Third   7.2500         0
# 2  26.0  female  Third   7.9250         1
# 4  35.0    male  Third   8.0500         0
# 5   NaN    male  Third   8.4583         0
# 7   2.0    male  Third  21.0750         0

# %% [markdown]
# ### 여러 열을 기준으로 그룹화

# %%
# class 열과 , sex 열을 기준으로 분할
grouped_two  = df.groupby(["class", "sex"], observed = True)

# %%
grouped_two

# %%
for key, group in grouped_two :
    print("*key : " , key)
    print("*group :" , len(group))
# Out:
# *key :  ('First', 'female')
# *group : 94
# *key :  ('First', 'male')
# *group : 122
# *key :  ('Second', 'female')
# *group : 76
# *key :  ('Second', 'male')
# *group : 108
# *key :  ('Third', 'female')
# *group : 144
# *key :  ('Third', 'male')
# *group : 347

# %%
# grouped_two 그룹에 연산 메소드를 적용해보자 

avg_two = grouped_two.mean()
avg_two
# Out:
#                      age        fare  survived
# class  sex
# First  female  34.611765  106.125798  0.968085
#        male    41.281386   67.226127  0.368852
# Second female  28.722973   21.970121  0.921053
#        male    30.740707   19.741782  0.157407
# Third  female  21.750000   16.118810  0.500000
#        male    26.507589   12.661633  0.135447

# %%
# grouped_two 그룹 객체에서 개별 그룹 선택하기

group3f = grouped_two.get_group(("Third", "female"))

# %%
group3f.head()
# Out:
#      age     sex  class     fare  survived
# 2   26.0  female  Third   7.9250         1
# 8   27.0  female  Third  11.1333         1
# 10   4.0  female  Third  16.7000         1
# 14  14.0  female  Third   7.8542         0
# 18  31.0  female  Third  18.0000         0

# %% [markdown]
# ## 그룹 연산 메소드

# %% [markdown]
# ### 집계 함수( 차원이 줄어들어요 )
#
# - 그룹 객체에 다양한 연산을 적용하는 과정
# - 집계 기능을 내장하고 있는 판다스 기본함수
# - mean()
# - max()
# - min()
# - sum()
# - count()
# - size()
# - var()
# - std()
# - describe()
# - info()
# - first()
# - last()

# %%
df.head()
# Out:
#     age     sex  class     fare  survived
# 0  22.0    male  Third   7.2500         0
# 1  38.0  female  First  71.2833         1
# 2  26.0  female  Third   7.9250         1
# 3  35.0  female  First  53.1000         1
# 4  35.0    male  Third   8.0500         0

# %%
grouped

# %%
# 각 그룹에 대한 모든 열의 표준 편차를 집계
grouped.std(numeric_only = True) # 컬럼이 (열 3개 행 3개 )여러개 ... 총 9 개 이렇게해서 데이터 프레임 형태가 된다!!!!!
# 차원을 줄여~~~!!~!~!~~!~!!~!~!!~!~!!!!~!!
# Out:
#               age       fare  survived
# class
# First   14.802856  78.380373  0.484026
# Second  14.001077  13.417399  0.500623
# Third   12.495398  11.778142  0.428949

# %%
# 각 그룹에 대한 fare 열의 표준편차를 집계
grouped["fare"].std() # 컬럼이 1개 니까 시리즈가 되지용~
# Out:
# class
# First     78.380373
# Second    13.417399
# Third     11.778142
# Name: fare, dtype: float64

# %%
# 직접 집계함수 만들기???
# 그룹 객체에 agg() 메소드 적용 - 사용자 정의 함수를 인수로 전달
def min_max(x):
    return x.max() - x.min()

# %% [markdown]
# - 집계 연산을 처리하는 사용자 정의 함수를 그룹 객체 에 적용하기 위해서 agg() 메소드 이용

# %%
grouped[["age","fare","survived"]].agg(min_max)
# Out:
#           age      fare  survived
# class
# First   79.08  512.3292         1
# Second  69.33   73.5000         1
# Third   73.58   69.5500         1

# %% [markdown]
# #### agg 함수를 이용해서 동시에 여러개의 함수를 사용하여 각 그룹별 데이터에 대한 집계연산을 처리
# - 각각의 열에 여러개의 함수를 일괄적용할때는 리스트 형태로 인수전달
# - 열마다 다른 종류의 함수를 전달하려면 딕셔너리 전달 {열 : 함수}

# %%
# 여러함수를 각 열에 동일하게 적용
grouped.agg(["min", "max"])
# Out:
#          age           sex       fare           survived
#          min   max     min   max  min       max      min max
# class
# First   0.92  80.0  female  male  0.0  512.3292        0   1
# Second  0.67  70.0  female  male  0.0   73.5000        0   1
# Third   0.42  74.0  female  male  0.0   69.5500        0   1

# %%
# 각 열 컬럼 적용
grouped.agg({"fare" : ["max", "min"], "age" : "mean"}) # 이거 많이 활용해주세요...
# Out:
#             fare             age
#              max  min       mean
# class
# First   512.3292  0.0  38.233441
# Second   73.5000  0.0  29.877630
# Third    69.5500  0.0  25.140620

# %%
# 3명의 ... 그 이야기...
# 모든 데이터의 평균을... 구했다고...

# %% [markdown]
# ### 그룹 객체 필터링
#
# - 그룹 객체에 filter() 메소드를 적용할 때 조건식을 가진 함수를 전달하여 조건이 참인 그룹만을 필터링

# %%
df
# Out:
#       age     fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %% [markdown]
# # 그룹한다음에 필터 쓰기

# %%
grouped = df.groupby(["class"])
# Out:
# C:\Users\ITSC\AppData\Local\Temp\ipykernel_7632\1291774395.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df.groupby(["class"])

# %%
for i, group in grouped:
    print("key : ", i)
    print("group : ", group)
# Out:
# key :  ('First',)
# group :        age     fare  class
# 1    38.0  71.2833  First
# 3    35.0  53.1000  First
# 6    54.0  51.8625  First
# 11   58.0  26.5500  First
# 23   28.0  35.5000  First
# ..    ...      ...    ...
# 871  47.0  52.5542  First
# 872  33.0   5.0000  First
# 879  56.0  83.1583  First
# 887  19.0  30.0000  First
# 889  26.0  30.0000  First
#
# [216 rows x 3 columns]
# key :  ('Second',)
# group :        age     fare   class
# 9    14.0  30.0708  Second
# 15   55.0  16.0000  Second
# 17    NaN  13.0000  Second
# 20   35.0  26.0000  Second
# 21   34.0  13.0000  Second
# ..    ...      ...     ...
# 866  27.0  13.8583  Second
# 874  28.0  24.0000  Second
# 880  25.0  26.0000  Second
# 883  28.0  10.5000  Second
# 886  27.0  13.0000  Second
#
# [184 rows x 3 columns]
# key :  ('Third',)
# group :        age     fare  class
# 0    22.0   7.2500  Third
# 2    26.0   7.9250  Third
# 4    35.0   8.0500  Third
# 5     NaN   8.4583  Third
# 7     2.0  21.0750  Third
# ..    ...      ...    ...
# 882  22.0  10.5167  Third
# 884  25.0   7.0500  Third
# 885  39.0  29.1250  Third
# 888   NaN  23.4500  Third
# 890  32.0   7.7500  Third
#
# [491 rows x 3 columns]

# %%
# 데이터 개수가 200개 이상인 그룹만을 필터링 하여 데이터프레임으로 반환 
grouped_filter = grouped.filter(lambda x : len(x) >= 200) # second 는 200 이상 안되기 때문에 필터링되어서안나옴

grouped_filter
# Out:
#       age     fare  class
# 0    22.0   7.2500  Third
# 1    38.0  71.2833  First
# 2    26.0   7.9250  Third
# 3    35.0  53.1000  First
# 4    35.0   8.0500  Third
# ..    ...      ...    ...
# 885  39.0  29.1250  Third
# 887  19.0  30.0000  First
# 888   NaN  23.4500  Third
# 889  26.0  30.0000  First
# 890  32.0   7.7500  Third
#
# [707 rows x 3 columns]

# %%
# age 열의 평균이 30보다 작은 그룹만을 필터링
age_filter = grouped.filter(lambda x : x["age"].mean() < 30)

# %%
age_filter.head()
# Out:
#     age     fare  class
# 0  22.0   7.2500  Third
# 2  26.0   7.9250  Third
# 4  35.0   8.0500  Third
# 5   NaN   8.4583  Third
# 7   2.0  21.0750  Third

# %%
age_filter["class"].unique() # 필터링된 class 의 고유값을 찍어봐라
# Out:
# ['Third', 'Second']
# Categories (3, object): ['First', 'Second', 'Third']

# %% [markdown]
# # 그룹객체에 함수 매핑

# %%
grouped.apply(lambda x : x.describe(), include_groups=False)
# Out:
#                      age        fare
# class
# First  count  186.000000  216.000000
#        mean    38.233441   84.154687
#        std     14.802856   78.380373
#        min      0.920000    0.000000
#        25%     27.000000   30.923950
#        50%     37.000000   60.287500
#        75%     49.000000   93.500000
#        max     80.000000  512.329200
# Second count  173.000000  184.000000
#        mean    29.877630   20.662183
#        std     14.001077   13.417399
#        min      0.670000    0.000000
#        25%     23.000000   13.000000
#        50%     29.000000   14.250000
#        75%     36.000000   26.000000
#        max     70.000000   73.500000
# Third  count  355.000000  491.000000
#        mean    25.140620   13.675550
#        std     12.495398   11.778142
#        min      0.420000    0.000000
#        25%     18.000000    7.750000
#        50%     24.000000    8.050000
#        75%     32.000000   15.500000
#        max     74.000000   69.550000

# %%
# 직접만든 함수 를 매핑
# 표준 점수를 계산하는 사용자 함수 정의

def z_scroe(x):
    return (x - x.mean()) / x.std()

# %%
grouped["age"].apply(z_scroe)
# Out:
# class
# First  1     -0.015770
#        3     -0.218434
#        6      1.065103
#        11     1.335321
#        23    -0.691315
#                 ...
# Third  882   -0.251342
#        884   -0.011254
#        885    1.109159
#        888         NaN
#        890    0.548953
# Name: age, Length: 891, dtype: float64

# %% [markdown]
# # 멀티 인덱스
#
# - 행 인덱스를 여러 레벨로 구현하는 것

# %%
df = titanic.loc[:, ["class","sex","age","fare","survived"]]

# %%
df.head()
# Out:
#    class     sex   age     fare  survived
# 0  Third    male  22.0   7.2500         0
# 1  First  female  38.0  71.2833         1
# 2  Third  female  26.0   7.9250         1
# 3  First  female  35.0  53.1000         1
# 4  Third    male  35.0   8.0500         0

# %%
# class 열, sex 열을 기준으로 분할
grouped = df.groupby(["class", "sex"], observed = True) # 멀티 인덱스 설정 class 와 sex 로

# %%
gdf = grouped.mean() # 그것들의 평균

# %%
gdf
# Out:
#                      age        fare  survived
# class  sex
# First  female  34.611765  106.125798  0.968085
#        male    41.281386   67.226127  0.368852
# Second female  28.722973   21.970121  0.921053
#        male    30.740707   19.741782  0.157407
# Third  female  21.750000   16.118810  0.500000
#        male    26.507589   12.661633  0.135447

# %%
# class 값이 First 인 행을 선택하여 출력
gdf.loc["First"] # 딱히 다르지 않다
# Out:
#               age        fare  survived
# sex
# female  34.611765  106.125798  0.968085
# male    41.281386   67.226127  0.368852

# %%
# class 값이 Frist 이고, sex 값이 female 인 행을 선ㅌ개하여 출력
gdf.loc[("First","female")]
# Out:
# age          34.611765
# fare        106.125798
# survived      0.968085
# Name: (First, female), dtype: float64

# %%
# 남성데이터만 볼래요
gdf.xs("male", level = "sex") # 단계 앞당기기
# Out:
#               age       fare  survived
# class
# First   41.281386  67.226127  0.368852
# Second  30.740707  19.741782  0.157407
# Third   26.507589  12.661633  0.135447

# %% [markdown]
# # 피벗

# %% [markdown]
# - 피벗 잘 쓰는 사람 = 엑셀 잘하는 사람

# %% [markdown]
# - pivot_table()
# - 엑셀에서 사용하는 피벗테이블과 비슷한 기능
# - 커다란 표의 데이터를 요약하는 통계표

# %%
df.head()
# Out:
#    class     sex   age     fare  survived
# 0  Third    male  22.0   7.2500         0
# 1  First  female  38.0  71.2833         1
# 2  Third  female  26.0   7.9250         1
# 3  First  female  35.0  53.1000         1
# 4  Third    male  35.0   8.0500         0

# %%
# 행, 열, 값, 집계에 사용할 열을 1개식 지정  - 평균 집계

pdf1 = pd.pivot_table(

    df,
    index = "class", # 행
    columns = "sex", # 컬럼에 성별
    values = "age", # 인스턴스에 들어갈 열,,
    aggfunc = "mean", # 그것의 연산... 집계함수 ( sum, min, max, mean...등을 한다)
    observed = True
)

# %%
pdf1
# Out:
# sex        female       male
# class
# First   34.611765  41.281386
# Second  28.722973  30.740707
# Third   21.750000  26.507589

# %%
# 값에 적용하는 집계함수를 2개 이상 지정 가능 - 생존율, 생존자 수 집계

pdf2 = pd.pivot_table (
     df,
    index = "class",
    columns = "sex",
    values = "survived", 
    aggfunc = ["mean","sum"], # 2개
    observed = True
)
pdf2
# Out:
#             mean              sum
# sex       female      male female male
# class
# First   0.968085  0.368852     91   45
# Second  0.921053  0.157407     70   17
# Third   0.500000  0.135447     72   47

# %%
# 행, 열, 값에 사용할 열을 2개 이상 지정가능 - 평균 나이, 최대 요금집계

df3 = pd.pivot_table(
    df,
    index = ["class", "sex"],
    columns = "survived",
    values = ["age", "fare"],
    aggfunc = ["mean", "max"],
    observed = True
)


df3


df3.style.set_properties(color="red", align="middle", background="#black" )
# Out:
# <style type="text/css">
# #T_86473_row0_col0, #T_86473_row0_col1, #T_86473_row0_col2, #T_86473_row0_col3, #T_86473_row0_col4, #T_86473_row0_col5, #T_86473_row0_col6, #T_86473_row0_col7, #T_86473_row1_col0, #T_86473_row1_col1, #T_86473_row1_col2, #T_86473_row1_col3, #T_86473_row1_col4, #T_86473_row1_col5, #T_86473_row1_col6, #T_86473_row1_col7, #T_86473_row2_col0, #T_86473_row2_col1, #T_86473_row2_col2, #T_86473_row2_col3, #T_86473_row2_col4, #T_86473_row2_col5, #T_86473_row2_col6, #T_86473_row2_col7, #T_86473_row3_col0, #T_86473_row3_col1, #T_86473_row3_col2, #T_86473_row3_col3, #T_86473_row3_col4, #T_86473_row3_col5, #T_86473_row3_col6, #T_86473_row3_col7, #T_86473_row4_col0, #T_86473_row4_col1, #T_86473_row4_col2, #T_86473_row4_col3, #T_86473_row4_col4, #T_86473_row4_col5, #T_86473_row4_col6, #T_86473_row4_col7, #T_86473_row5_col0, #T_86473_row5_col1, #T_86473_row5_col2, #T_86473_row5_col3, #T_86473_row5_col4, #T_86473_row5_col5, #T_86473_row5_col6, #T_86473_row5_col7 {
#   color: red;
#   align: middle;
#   index_background: #black;
# }
# </style>
# <table id="T_86473">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86473_level0_col0" class="col_heading level0 col0" colspan="4">mean</th>
#       <th id="T_86473_level0_col4" class="col_heading level0 col4" colspan="4">max</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_86473_level1_col0" class="col_heading level1 col0" colspan="2">age</th>
#       <th id="T_86473_level1_col2" class="col_heading level1 col2" colspan="2">fare</th>
#       <th id="T_86473_level1_col4" class="col_heading level1 col4" colspan="2">age</th>
#       <th id="T_86473_level1_col6" class="col_heading level1 col6" colspan="2">fare</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level2" >survived</th>
#       <th id="T_86473_level2_col0" class="col_heading level2 col0" >0</th>
#       <th id="T_86473_level2_col1" class="col_heading level2 col1" >1</th>
#       <th id="T_86473_level2_col2" class="col_heading level2 col2" >0</th>
#       <th id="T_86473_level2_col3" class="col_heading level2 col3" >1</th>
#       <th id="T_86473_level2_col4" class="col_heading level2 col4" >0</th>
#       <th id="T_86473_level2_col5" class="col_heading level2 col5" >1</th>
#       <th id="T_86473_level2_col6" class="col_heading level2 col6" >0</th>
#       <th id="T_86473_level2_col7" class="col_heading level2 col7" >1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >class</th>
#       <th class="index_name level1" >sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86473_level0_row0" class="row_heading level0 row0" rowspan="2">First</th>
#       <th id="T_86473_level1_row0" class="row_heading level1 row0" >female</th>
#       <td id="T_86473_row0_col0" class="data row0 col0" >25.666667</td>
#       <td id="T_86473_row0_col1" class="data row0 col1" >34.939024</td>
#       <td id="T_86473_row0_col2" class="data row0 col2" >110.604167</td>
#       <td id="T_86473_row0_col3" class="data row0 col3" >105.978159</td>
#       <td id="T_86473_row0_col4" class="data row0 col4" >50.000000</td>
#       <td id="T_86473_row0_col5" class="data row0 col5" >63.000000</td>
#       <td id="T_86473_row0_col6" class="data row0 col6" >151.550000</td>
#       <td id="T_86473_row0_col7" class="data row0 col7" >512.329200</td>
#     </tr>
#     <tr>
#       <th id="T_86473_level1_row1" class="row_heading level1 row1" >male</th>
#       <td id="T_86473_row1_col0" class="data row1 col0" >44.581967</td>
#       <td id="T_86473_row1_col1" class="data row1 col1" >36.248000</td>
#       <td id="T_86473_row1_col2" class="data row1 col2" >62.894910</td>
#       <td id="T_86473_row1_col3" class="data row1 col3" >74.637320</td>
#       <td id="T_86473_row1_col4" class="data row1 col4" >71.000000</td>
#       <td id="T_86473_row1_col5" class="data row1 col5" >80.000000</td>
#       <td id="T_86473_row1_col6" class="data row1 col6" >263.000000</td>
#       <td id="T_86473_row1_col7" class="data row1 col7" >512.329200</td>
#     </tr>
#     <tr>
#       <th id="T_86473_level0_row2" class="row_heading level0 row2" rowspan="2">Second</th>
#       <th id="T_86473_level1_row2" class="row_heading level1 row2" >female</th>
#       <td id="T_86473_row2_col0" class="data row2 col0" >36.000000</td>
#       <td id="T_86473_row2_col1" class="data row2 col1" >28.080882</td>
#       <td id="T_86473_row2_col2" class="data row2 col2" >18.250000</td>
#       <td id="T_86473_row2_col3" class="data row2 col3" >22.288989</td>
#       <td id="T_86473_row2_col4" class="data row2 col4" >57.000000</td>
#       <td id="T_86473_row2_col5" class="data row2 col5" >55.000000</td>
#       <td id="T_86473_row2_col6" class="data row2 col6" >26.000000</td>
#       <td id="T_86473_row2_col7" class="data row2 col7" >65.000000</td>
#     </tr>
#     <tr>
#       <th id="T_86473_level1_row3" class="row_heading level1 row3" >male</th>
#       <td id="T_86473_row3_col0" class="data row3 col0" >33.369048</td>
#       <td id="T_86473_row3_col1" class="data row3 col1" >16.022000</td>
#       <td id="T_86473_row3_col2" class="data row3 col2" >19.488965</td>
#       <td id="T_86473_row3_col3" class="data row3 col3" >21.095100</td>
#       <td id="T_86473_row3_col4" class="data row3 col4" >70.000000</td>
#       <td id="T_86473_row3_col5" class="data row3 col5" >62.000000</td>
#       <td id="T_86473_row3_col6" class="data row3 col6" >73.500000</td>
#       <td id="T_86473_row3_col7" class="data row3 col7" >39.000000</td>
#     </tr>
#     <tr>
#       <th id="T_86473_level0_row4" class="row_heading level0 row4" rowspan="2">Third</th>
#       <th id="T_86473_level1_row4" class="row_heading level1 row4" >female</th>
#       <td id="T_86473_row4_col0" class="data row4 col0" >23.818182</td>
#       <td id="T_86473_row4_col1" class="data row4 col1" >19.329787</td>
#       <td id="T_86473_row4_col2" class="data row4 col2" >19.773093</td>
#       <td id="T_86473_row4_col3" class="data row4 col3" >12.464526</td>
#       <td id="T_86473_row4_col4" class="data row4 col4" >48.000000</td>
#       <td id="T_86473_row4_col5" class="data row4 col5" >63.000000</td>
#       <td id="T_86473_row4_col6" class="data row4 col6" >69.550000</td>
#       <td id="T_86473_row4_col7" class="data row4 col7" >31.387500</td>
#     </tr>
#     <tr>
#       <th id="T_86473_level1_row5" class="row_heading level1 row5" >male</th>
#       <td id="T_86473_row5_col0" class="data row5 col0" >27.255814</td>
#       <td id="T_86473_row5_col1" class="data row5 col1" >22.274211</td>
#       <td id="T_86473_row5_col2" class="data row5 col2" >12.204469</td>
#       <td id="T_86473_row5_col3" class="data row5 col3" >15.579696</td>
#       <td id="T_86473_row5_col4" class="data row5 col4" >74.000000</td>
#       <td id="T_86473_row5_col5" class="data row5 col5" >45.000000</td>
#       <td id="T_86473_row5_col6" class="data row5 col6" >69.550000</td>
#       <td id="T_86473_row5_col7" class="data row5 col7" >56.495800</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 열심히 공부해 보자요
